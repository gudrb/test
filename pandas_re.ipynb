# %%
from pandas import Series,DataFrame
raw_data = {'col0':[1,2,3,4],
            'col1':[10,20,30,40],
            'col2':[100,200,300,400]}
data = DataFrame(raw_data)
print(data)
# Out:
#    col0  col1  col2
# 0     1    10   100
# 1     2    20   200
# 2     3    30   300
# 3     4    40   400

# %%
data['col0']
data['col1']
data['col2']
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# Name: col2, dtype: int64

# %%
type(data['col0'])
# Out:
# pandas.core.series.Series

# %%
daeshin = {'open':  [11650, 11100, 11200, 11100, 11000],
           'high':  [12100, 11800, 11200, 11100, 11150],
           'low' :  [11600, 11050, 10900, 10950, 10900],
           'close': [11900, 11600, 11000, 11100, 11050]}
daeshin_day=DataFrame(daeshin,columns=['open','high','low','close'],index=['16.02.29','16.02.26','16.02.25','16.02.24','16.02.23'])
daeshin_day
# Out:
#            open   high    low  close
# 16.02.29  11650  12100  11600  11900
# 16.02.26  11100  11800  11050  11600
# 16.02.25  11200  11200  10900  11000
# 16.02.24  11100  11100  10950  11100
# 16.02.23  11000  11150  10900  11050

# %%
close = daeshin_day['close']
print(close)
# Out:
# 16.02.29    11900
# 16.02.26    11600
# 16.02.25    11000
# 16.02.24    11100
# 16.02.23    11050
# Name: close, dtype: int64

# %% [markdown]
# print(daeshin_day['16.02.24']) #16.02.24 is not key , so it is error

# %%
day_data = daeshin_day.ix['16.02.24']
print(day_data)
print(type(day_data))
# Out:
# open     11100
# high     11100
# low      10950
# close    11100
# Name: 16.02.24, dtype: int64
# <class 'pandas.core.series.Series'>
# C:\Users\gudrb\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
print(daeshin_day.columns)
print(daeshin_day.index)
# Out:
# Index(['open', 'high', 'low', 'close'], dtype='object')
# Index(['16.02.29', '16.02.26', '16.02.25', '16.02.24', '16.02.23'], dtype='object')

# %% [markdown]
# operate anaconda and commend ipython

# %%
import pandas_datareader.data as web

# %%
import datetime

# %%
start=datetime.datetime(2010,2,19)
print(start)
# Out:
# 2010-02-19 00:00:00

# %%
end=datetime.datetime(2016,3,4)

# %%
gs=web.DataReader('^DJI', 'stooq',start,end)
gs
# Out:
#                 Open      High       Low     Close       Volume
# Date
# 2018-07-17  25033.92  25155.39  24989.61  25119.89          NaN
# 2018-07-16  25025.58  25072.41  24979.64  25064.36   78889304.0
# 2018-07-13  24926.07  25043.21  24890.06  25019.41   78989320.0
# 2018-07-12  24802.90  24939.97  24802.90  24924.89   78658616.0
# 2018-07-11  24789.48  24815.16  24663.82  24700.45   77924224.0
# 2018-07-10  24806.97  24945.38  24806.97  24919.66   78618376.0
# 2018-07-09  24525.23  24796.29  24525.23  24776.59   80515008.0
# 2018-07-06  24352.47  24520.29  24281.47  24456.48   84739696.0
# 2018-07-05  24285.82  24372.80  24177.44  24356.74   88005704.0
# 2018-07-03  24359.39  24444.88  24150.85  24174.82   64243968.0
# 2018-07-02  24161.53  24319.42  24077.56  24307.18   91452984.0
# 2018-06-29  24323.93  24509.52  24269.71  24271.41  126101120.0
# 2018-06-28  24064.19  24308.16  23997.21  24216.05   95902528.0
# 2018-06-27  24303.11  24569.02  24115.82  24117.59  117435992.0
# ...

# %%
gs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 31670 entries, 2018-07-17 to 1896-05-27
# Data columns (total 5 columns):
# Open      31670 non-null float64
# High      31670 non-null float64
# Low       31670 non-null float64
# Close     31670 non-null float64
# Volume    23221 non-null float64
# dtypes: float64(5)
# memory usage: 1.4 MB

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(gs['Close'])
plt.show()

# %%
gs.index
# Out:
# DatetimeIndex(['2018-07-17', '2018-07-16', '2018-07-13', '2018-07-12',
#                '2018-07-11', '2018-07-10', '2018-07-09', '2018-07-06',
#                '2018-07-05', '2018-07-03',
#                ...
#                '1896-06-09', '1896-06-08', '1896-06-05', '1896-06-04',
#                '1896-06-03', '1896-06-02', '1896-06-01', '1896-05-29',
#                '1896-05-28', '1896-05-27'],
#               dtype='datetime64[ns]', name='Date', length=31670, freq=None)

# %%
plt.plot(gs.index,gs['Close'])
plt.show()

# %%
technical analysis - 이동평균선
:일정 기간 동안의 주가를 산술 평균한 값인 주가 이동평균을 차례로 연결해 만든 선
    산술평균(여러 수의 합을 그 개수로 나눈 값)
    주가이동평균(일정 기간의 주가를 산술 평균한 값)

# %%
gs = gs=web.DataReader('^DJI', 'stooq','2014-01-01','2016-03-06')
gs
# Out:
#                 Open      High       Low     Close       Volume
# Date
# 2018-07-17  25033.92  25155.39  24989.61  25119.89          NaN
# 2018-07-16  25025.58  25072.41  24979.64  25064.36   78889304.0
# 2018-07-13  24926.07  25043.21  24890.06  25019.41   78989320.0
# 2018-07-12  24802.90  24939.97  24802.90  24924.89   78658616.0
# 2018-07-11  24789.48  24815.16  24663.82  24700.45   77924224.0
# 2018-07-10  24806.97  24945.38  24806.97  24919.66   78618376.0
# 2018-07-09  24525.23  24796.29  24525.23  24776.59   80515008.0
# 2018-07-06  24352.47  24520.29  24281.47  24456.48   84739696.0
# 2018-07-05  24285.82  24372.80  24177.44  24356.74   88005704.0
# 2018-07-03  24359.39  24444.88  24150.85  24174.82   64243968.0
# 2018-07-02  24161.53  24319.42  24077.56  24307.18   91452984.0
# 2018-06-29  24323.93  24509.52  24269.71  24271.41  126101120.0
# 2018-06-28  24064.19  24308.16  23997.21  24216.05   95902528.0
# 2018-06-27  24303.11  24569.02  24115.82  24117.59  117435992.0
# ...

# %%
gs.tail()
# Out:
#              Open   High    Low  Close  Volume
# Date
# 1896-06-02  29.00  29.00  29.00  29.00     NaN
# 1896-06-01  29.40  29.40  29.40  29.40     NaN
# 1896-05-29  29.43  29.43  29.43  29.43     NaN
# 1896-05-28  29.11  29.11  29.11  29.11     NaN
# 1896-05-27  29.39  29.39  29.39  29.39     NaN

# %%
new_gs=gs[gs['Volume']!=0]# the day only it have volume
#new_gs=gs['Volume]!=0 -> new_gs only include index,volume(!=0)

# %%
new_gs.tail(5)
# Out:
#              Open   High    Low  Close  Volume
# Date
# 1896-06-02  29.00  29.00  29.00  29.00     NaN
# 1896-06-01  29.40  29.40  29.40  29.40     NaN
# 1896-05-29  29.43  29.43  29.43  29.43     NaN
# 1896-05-28  29.11  29.11  29.11  29.11     NaN
# 1896-05-27  29.39  29.39  29.39  29.39     NaN

# %%
ma5=new_gs['Close'].rolling(window=5).mean() #주가 이동평균
ma5.tail(10)
# Out:
# Date
# 1896-06-09    28.448
# 1896-06-08    28.430
# 1896-06-05    28.576
# 1896-06-04    28.654
# 1896-06-03    28.850
# 1896-06-02    28.952
# 1896-06-01    29.066
# 1896-05-29    29.112
# 1896-05-28    29.148
# 1896-05-27    29.266
# Name: Close, dtype: float64

# %%
new_gs.insert(len(new_gs.columns),"MA5",ma5)#place which add column,name of column,data

# %%
new_gs.tail(5)
# Out:
#              Open   High    Low  Close  Volume     MA5
# Date
# 1896-06-02  29.00  29.00  29.00  29.00     NaN  28.952
# 1896-06-01  29.40  29.40  29.40  29.40     NaN  29.066
# 1896-05-29  29.43  29.43  29.43  29.43     NaN  29.112
# 1896-05-28  29.11  29.11  29.11  29.11     NaN  29.148
# 1896-05-27  29.39  29.39  29.39  29.39     NaN  29.266

# %%
ma20=new_gs['Close'].rolling(window=20).mean()
ma60=new_gs['Close'].rolling(window=60).mean()
ma120=new_gs['Close'].rolling(window=120).mean()
new_gs.insert(len(new_gs.columns),"MA20",ma20)
new_gs.insert(len(new_gs.columns),"MA60",ma60)
new_gs.insert(len(new_gs.columns),"MA120",ma120)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-80b31303cbf4> in <module>()
#       2 ma60=new_gs['Close'].rolling(window=60).mean()
#       3 ma120=new_gs['Close'].rolling(window=120).mean()
# ----> 4 new_gs.insert(len(new_gs.columns),"MA20",ma20)
#       5 new_gs.insert(len(new_gs.columns),"MA60",ma60)
#       6 new_gs.insert(len(new_gs.columns),"MA120",ma120)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    2611         value = self._sanitize_column(column, value, broadcast=False)
#    2612         self._data.insert(loc, column, value,
# -> 2613                           allow_duplicates=allow_duplicates)
#    2614
#    2615     def assign(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in insert(self, loc, item, value, allow_duplicates)
# ...

# %%
new_gs.tail(10)
# Out:
#              Open   High    Low  Close  Volume     MA5     MA20       MA60  \
# Date
# 1896-06-09  28.49  28.49  28.49  28.49     NaN  28.448  27.4835  24.358833
# 1896-06-08  28.83  28.83  28.83  28.83     NaN  28.430  27.6625  24.453500
# 1896-06-05  29.20  29.20  29.20  29.20     NaN  28.576  27.8645  24.567500
# 1896-06-04  28.93  28.93  28.93  28.93     NaN  28.654  28.0470  24.683833
# 1896-06-03  28.80  28.80  28.80  28.80     NaN  28.850  28.2345  24.798167
# 1896-06-02  29.00  29.00  29.00  29.00     NaN  28.952  28.3755  24.912000
# 1896-06-01  29.40  29.40  29.40  29.40     NaN  29.066  28.5590  25.031833
# 1896-05-29  29.43  29.43  29.43  29.43     NaN  29.112  28.6585  25.153500
# 1896-05-28  29.11  29.11  29.11  29.11     NaN  29.148  28.7390  25.267833
# 1896-05-27  29.39  29.39  29.39  29.39     NaN  29.266  28.8225  25.379667
#
#                 MA120
# Date
# 1896-06-09  25.950083
# 1896-06-08  25.934000
# 1896-06-05  25.919583
# 1896-06-04  25.901417
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(new_gs.index,new_gs['Close'],label='Close')#add lable

# %%
plt.plot(new_gs.index,new_gs['MA5'],label='MA5')#add lable
plt.plot(new_gs.index,new_gs['MA20'],label='MA20')
plt.plot(new_gs.index,new_gs['MA60'],label='MA60')
plt.plot(new_gs.index,new_gs['MA120'],label='MA120')
plt.legend(loc='best')# legend-> show lable, loc -> location if label
